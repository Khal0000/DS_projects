# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mpl
import seaborn as sns

# %%
df = pd.read_csv('Binance_BTCUSDT_d.csv')
df
# Out:
#               unix                 date    symbol      open      high  \
# 0     1.657066e+12  2022-07-06 00:00:00  BTC/USDT  20175.84  20265.28
# 1     1.656979e+12  2022-07-05 00:00:00  BTC/USDT  20236.71  20750.00
# 2     1.656893e+12  2022-07-04 00:00:00  BTC/USDT  19315.83  20354.01
# 3     1.656806e+12  2022-07-03 00:00:00  BTC/USDT  19252.82  19647.63
# 4     1.656720e+12  2022-07-02 00:00:00  BTC/USDT  19279.80  19467.39
# ...            ...                  ...       ...       ...       ...
# 1781  1.503274e+09           2017-08-21  BTC/USDT   4086.29   4119.62
# 1782  1.503187e+09           2017-08-20  BTC/USDT   4139.98   4211.08
# 1783  1.503101e+09           2017-08-19  BTC/USDT   4108.37   4184.69
# 1784  1.503014e+09           2017-08-18  BTC/USDT   4285.08   4371.52
# 1785  1.502928e+09           2017-08-17  BTC/USDT   4469.93   4485.39
#
#            low     close   Volume BTC   Volume USDT  tradecount
# ...

# %%
# print(df['tradecount'].unique().tolist())
print(df['tradecount'].nunique())
# Out:
# 1660

# %%
df.isnull().sum()
# Out:
# unix             0
# date             0
# symbol           0
# open             0
# high             0
# low              0
# close            0
# Volume BTC       0
# Volume USDT      0
# tradecount     124
# dtype: int64
